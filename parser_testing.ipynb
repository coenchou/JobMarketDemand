# %% [markdown]
# # Parser Testing Notebook
#
# This notebook runs the resume parser on each sample resume in its own cell so you can inspect the output one file at a time.
#
# The parser script is expected to be available at `src/parser.py` and the resumes are under `resumes/`.

# %%
import json
from pathlib import Path

from src.parser import parse_resume_file

ROOT = Path.cwd()
RESUME_DIR = ROOT / 'resumes'
OUTPUT_DIR = ROOT / 'outputs' / 'parser'
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print('ROOT:', ROOT)
print('RESUME_DIR:', RESUME_DIR)
print('OUTPUT_DIR:', OUTPUT_DIR)
# Out:
# ROOT: /Users/coenchou/JobMarketDemand
# RESUME_DIR: /Users/coenchou/JobMarketDemand/resumes
# OUTPUT_DIR: /Users/coenchou/JobMarketDemand/outputs/parser

# %%
def run_parser_for_resume(resume_path: str):
    path = Path(resume_path)
    if not path.exists():
        raise FileNotFoundError(f'Resume not found: {path}')

    result = parse_resume_file(str(path))
    output_path = OUTPUT_DIR / f"{path.stem}.json"
    output_path.write_text(json.dumps(result, indent=2, ensure_ascii=False), encoding='utf-8')
    print(f'Parsed {path.name}')
    print(f'Wrote {output_path}')
    return result

# %%
resume_files = sorted(RESUME_DIR.glob('*.txt'))
resume_files
# Out:
# [PosixPath('/Users/coenchou/JobMarketDemand/resumes/resume_1_data_analyst.txt'),
#  PosixPath('/Users/coenchou/JobMarketDemand/resumes/resume_2_software_engineer.txt'),
#  PosixPath('/Users/coenchou/JobMarketDemand/resumes/resume_3_recent_graduate.txt'),
#  PosixPath('/Users/coenchou/JobMarketDemand/resumes/resume_4_career_changer.txt'),
#  PosixPath('/Users/coenchou/JobMarketDemand/resumes/resume_5_senior_ml_engineer.txt')]

# %%
resume_1 = resume_files[0]
resume_1
# Out:
# PosixPath('/Users/coenchou/JobMarketDemand/resumes/resume_1_data_analyst.txt')

# %%
result_1 = run_parser_for_resume(resume_1)
result_1
# Out:
# Parsed resume_1_data_analyst.txt
# Wrote /Users/coenchou/JobMarketDemand/outputs/parser/resume_1_data_analyst.json
# {'resume': 'resume_1_data_analyst.txt',
#  'skills': ['Programming: Python (pandas',
#   'NumPy',
#   'scikit-learn',
#   'matplotlib)',
#   'SQL',
#   'R (basic)',
#   'Visualization: Tableau',
#   'Power BI',
#   'Excel',
#   'Databases: PostgreSQL',
#   'MySQL',
#   'Google BigQuery',
#   'Other: A/B testing',
#   'statistical analysis',
#   'regression modeling',
#   'data cleaning',
#   'Git',
#   'Visualization',
#   'Scikit-learn',
#   'Programming',
#   'PostgreSQL',
#   'LinkedIn',
#   'BigQuery',
#   'Science',
#   'Tableau',
#   'pandas',
#   'Google',
#   'Python'],
#  'mapped_skills': [{'original': 'Programming: Python (pandas',
#    'mapped_element': None},
#   {'original': 'NumPy', 'mapped_element': None},
#   {'original': 'scikit-learn', 'mapped_element': None},
#   {'original': 'matplotlib)', 'mapped_element': None},
#   {'original': 'SQL', 'mapped_element': None},
#   {'original': 'R (basic)', 'mapped_element': None},
#   {'original': 'Visualization: Tableau', 'mapped_element': None},
#   {'original': 'Power BI', 'mapped_element': None},
#   {'original': 'Excel', 'mapped_element': None},
#   {'original': 'Databases: PostgreSQL', 'mapped_element': None},
#   {'original': 'MySQL', 'mapped_element': None},
#   {'original': 'Google BigQuery', 'mapped_element': None},
#   {'original': 'Other: A/B testing', 'mapped_element': None},
#   {'original': 'statistical analysis', 'mapped_element': None},
#   {'original': 'regression modeling', 'mapped_element': None},
#   {'original': 'data cleaning', 'mapped_element': None},
#   {'original': 'Git', 'mapped_element': None},
#   {'original': 'Visualization', 'mapped_element': None},
#   {'original': 'Scikit-learn', 'mapped_element': None},
#   {'original': 'Programming', 'mapped_element': None},
#   {'original': 'PostgreSQL', 'mapped_element': None},
#   {'original': 'LinkedIn', 'mapped_element': None},
#   {'original': 'BigQuery', 'mapped_element': None},
#   {'original': 'Science', 'mapped_element': 'Science'},
#   {'original': 'Tableau', 'mapped_element': None},
#   {'original': 'pandas', 'mapped_element': None},
#   {'original': 'Google', 'mapped_element': None},
#   {'original': 'Python', 'mapped_element': None}],
#  'soc_candidates': [{'soc_code': '17-2199', 'score': 16},
#   {'soc_code': '13-1041', 'score': 14},
#   {'soc_code': '11-3051', 'score': 12},
#   {'soc_code': '11-9199', 'score': 12},
#   {'soc_code': '15-1299', 'score': 12}],
#  'education': ['Bachelor of Science in Statistics',
#   'University of California, Davis | Graduated May 2019'],
#  'experience_lines': ['Data Analyst — TechRetail Inc., San Francisco, CA',
#   'June 2021 – Present',
#   'Analyzed customer purchase behavior across 2M+ records using SQL and Python, identifying trends that informed a 12% increase in upsell revenue',
#   'Built automated reporting dashboards in Tableau connected to live PostgreSQL databases',
#   'Conducted A/B testing on marketing campaigns, applying statistical significance testing to evaluate results',
#   'Collaborated with product and marketing teams to define KPIs and track weekly performance metrics',
#   'Cleaned and processed messy datasets using pandas and NumPy, reducing data errors by 40%',
#   'Junior Data Analyst — Bright Analytics, Oakland, CA',
#   'August 2019 – May 2021',
#   'Wrote complex SQL queries to extract and aggregate sales data from multiple relational databases',
#   'Created Excel-based reports and pivot tables for weekly executive summaries',
#   'Assisted senior analysts in building regression models to forecast quarterly revenue',
#   'Maintained data pipelines and flagged data quality issues to the engineering team'],
#  'years_experience_est': 3}

# %%
resume_2 = resume_files[1]
resume_2
# Out:
# PosixPath('/Users/coenchou/JobMarketDemand/resumes/resume_2_software_engineer.txt')

# %%
result_2 = run_parser_for_resume(resume_2)
result_2
# Out:
# Parsed resume_2_software_engineer.txt
# Wrote /Users/coenchou/JobMarketDemand/outputs/parser/resume_2_software_engineer.json
# {'resume': 'resume_2_software_engineer.txt',
#  'skills': ['Languages: Python',
#   'JavaScript',
#   'TypeScript',
#   'SQL',
#   'HTML/CSS',
#   'Frameworks: FastAPI',
#   'Django',
#   'React',
#   'Node.js',
#   'Express',
#   'Cloud & DevOps: AWS (EC2',
#   'S3',
#   'Lambda)',
#   'Docker',
#   'Kubernetes',
#   'GitHub Actions',
#   'Databases: PostgreSQL',
#   'MongoDB',
#   'Redis',
#   'Other: REST APIs',
#   'microservices',
#   'agile/scrum',
#   'system design',
#   'Git',
#   'code review',
#   'mentoring',
#   'Microservices Architecture',
#   'Programming',
#   'RESTful API',
#   'PostgreSQL',
#   'Science',
#   'Design',
#   'Google',
#   'Python',
#   'GitHub'],
#  'mapped_skills': [{'original': 'Languages: Python', 'mapped_element': None},
#   {'original': 'JavaScript', 'mapped_element': None},
#   {'original': 'TypeScript', 'mapped_element': None},
#   {'original': 'SQL', 'mapped_element': None},
#   {'original': 'HTML/CSS', 'mapped_element': None},
#   {'original': 'Frameworks: FastAPI', 'mapped_element': None},
#   {'original': 'Django', 'mapped_element': None},
#   {'original': 'React', 'mapped_element': None},
#   {'original': 'Node.js', 'mapped_element': None},
#   {'original': 'Express', 'mapped_element': None},
#   {'original': 'Cloud & DevOps: AWS (EC2', 'mapped_element': None},
#   {'original': 'S3', 'mapped_element': None},
#   {'original': 'Lambda)', 'mapped_element': None},
#   {'original': 'Docker', 'mapped_element': None},
#   {'original': 'Kubernetes', 'mapped_element': None},
#   {'original': 'GitHub Actions', 'mapped_element': None},
#   {'original': 'Databases: PostgreSQL', 'mapped_element': None},
#   {'original': 'MongoDB', 'mapped_element': None},
#   {'original': 'Redis', 'mapped_element': None},
#   {'original': 'Other: REST APIs', 'mapped_element': None},
#   {'original': 'microservices', 'mapped_element': None},
#   {'original': 'agile/scrum', 'mapped_element': None},
#   {'original': 'system design', 'mapped_element': None},
#   {'original': 'Git', 'mapped_element': None},
#   {'original': 'code review', 'mapped_element': None},
#   {'original': 'mentoring', 'mapped_element': None},
#   {'original': 'Microservices Architecture', 'mapped_element': None},
#   {'original': 'Programming', 'mapped_element': None},
#   {'original': 'RESTful API', 'mapped_element': None},
#   {'original': 'PostgreSQL', 'mapped_element': None},
#   {'original': 'Science', 'mapped_element': 'Science'},
#   {'original': 'Design', 'mapped_element': 'Design'},
#   {'original': 'Google', 'mapped_element': None},
#   {'original': 'Python', 'mapped_element': None},
#   {'original': 'GitHub', 'mapped_element': None}],
#  'soc_candidates': [{'soc_code': '17-2199', 'score': 32},
#   {'soc_code': '13-1041', 'score': 28},
#   {'soc_code': '11-3051', 'score': 24},
#   {'soc_code': '11-9199', 'score': 24},
#   {'soc_code': '15-1299', 'score': 24}],
#  'education': ['Bachelor of Science in Computer Science',
#   'University of Illinois Urbana-Champaign | Graduated May 2019'],
#  'experience_lines': ['Senior Software Engineer — FinTech Solutions LLC, Chicago, IL',
#   'March 2022 – Present',
#   'Designed and built a RESTful API serving 500K daily requests using Python and FastAPI, deployed on AWS',
#   'Led migration of monolithic application to microservices architecture, reducing deployment time by 60%',
#   'Implemented CI/CD pipelines using GitHub Actions and Docker, cutting release cycles from 2 weeks to 2 days',
#   'Mentored 3 junior engineers through code reviews, pair programming, and weekly 1-on-1s',
#   'Optimised database queries in PostgreSQL, reducing average query time by 35%',
#   'Software Engineer — Webcraft Agency, Chicago, IL',
#   'January 2020 – February 2022',
#   'Developed full-stack features for 8 client web applications using React, Node.js, and MongoDB',
#   'Built reusable React component library adopted across 5 internal projects',
#   'Integrated third-party APIs including Stripe payments, Twilio SMS, and Google Maps',
#   'Participated in agile sprint planning, daily standups, and retrospectives',
#   'Software Engineering Intern — DevBase Inc., Remote',
#   'June 2019 – December 2019',
#   'Contributed to backend services in Python and wrote unit tests using pytest',
#   'Fixed bugs and improved documentation across legacy codebase'],
#  'years_experience_est': 5}

# %%
resume_3 = resume_files[2]
resume_3

# %%
result_3 = run_parser_for_resume(resume_3)
result_3

# %%
for resume_path in resume_files:
    print(f'--- {resume_path.name} ---')
    try:
        parsed = run_parser_for_resume(str(resume_path))
        print('skills:', parsed.get('skills', [])[:10])
        print('education:', parsed.get('education', []))
        print('soc_candidates:', parsed.get('soc_candidates', []))
    except Exception as exc:
        print(f'ERROR for {resume_path.name}: {exc}')

# %%
for resume_path in resume_files:
    print(f'Checking {resume_path.name}')
    print('exists:', resume_path.exists())
    print('size:', resume_path.stat().st_size if resume_path.exists() else 'n/a')
